# %%
import pandas as pd

# %%
df = pd.read_csv("report_card.csv")

# %%
df.head()
# Out:
#    id                     created_at                     updated_at  \
# 0   1  2024-10-08 05:19:11.764442+00  2024-10-08 05:19:11.764442+00
# 1   2  2024-10-08 05:19:11.764442+00  2024-10-08 05:19:11.764442+00
# 2   3  2024-10-08 05:19:11.764442+00  2024-10-08 05:19:11.764442+00
# 3   4  2024-10-08 05:19:11.764442+00  2024-10-08 05:19:11.764442+00
# 4   5  2024-10-08 05:19:11.764442+00  2024-10-08 05:19:11.764442+00
#
#                              name  \
# 0  Aerodynamic Copper Knife trend
# 1              Orders with People
# 2           Revenue per age group
# 3             Buyers by age group
# 4     Heavy-Duty Silk Chair trend
#
#                                          description      display  \
# 0  Compares the total number of orders placed for...  smartscalar
# 1                                                NaN        table
# 2         Shows the revenue distributed by age group          bar
# 3  Shows a distribution of our customers in age g...          bar
# ...
